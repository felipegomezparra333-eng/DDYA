# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "felipe gomez parra" # @param {"type":"string"}
carnet = 1000115115 # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**

# %% [markdown]
# Una tienda en Colombia necesita desarrollar un programa que calcule la menor cantidad de monedas necesarias para entregar un cambio determinado a un cliente.
#
# La tienda dispone de las siguientes monedas:
#
# monedas = [50, 100, 200, 500, 1000]
# El usuario deberá ingresar el valor del cambio que necesita entregar.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**

# %% [markdown]
# Requerimientos Funcionales
# - El usuario ingresa un valor n diferente de 0 y negativo, n solo puede ser un numero natural distinto de 0
# - El programa debe leer n
# - El programa debe calcular el cambio solo con las denominaciones disponibles [1000, 500, 200, 100, 50].
# - Si el valor n no es multiplo de 50 dar una advertencia.
#
# Requerimientos no funcionales
# - El codigo debe ser legible y entendide de manera que se use un lenguaje de python comprensible.
# - La interfaz debe solicitar datos e informar el resultado con mensajes claros e intuitivos.
# -

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**

# %% [markdown]
# Historia de usuario 1: Entrada de datos por el cajero
# - Como cajero de la tienda,
#
#   Quiero ingresar el valor total del cambio del cliente,
#
#   Para calcular de manera automática y rápida las monedas que debo entregar.
#
#   Criterios de Aceptación: Debe recibir números enteros positivos, debe mostrar un mensaje explicativo si se ingresa un valor negativo o no numérico.
#
# Historia 2: Cálculo optimizado de cambio
# - Como sistema de la tienda,
#
#   Quiero procesar el monto ingresado priorizando siempre las monedas de mayor valor,
#
#   Para minimizar el número total de monedas entregadas.
#
#   Criterios de Aceptación: Para $1850$, debe devolver exactamente $5$ monedas ($1000 + 500 + 200 + 100 + 50$).Para $2000$, debe devolver $2$ monedas ($1000 \times 2$).
#
#
# Historia 3: Validación de denomaciones válidas
# - Como cajero de la tienda,
#
#   Quiero que el sistema detecte si un monto no se puede dar de forma exacta con la denominación mínima de $50$,
#
#   Para avisarme que no es posible entregar el cambio exacto.
#
#   Criterios de Aceptación:Si el cliente ingresa $1825$, debe indicar un error o retorno indicando que no es exacto.

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5) Diagramas de secuencia **[5 pts]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 6) Diagramas de casos de uso **[5 pts]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 7) Análisis de complejidad **[5 pts]**
#
# Estrategia: Se utiliza programación dinámica con memorización. El programa guarda los resultados que ya calculó para no repetirlos.
#
# Función T(n): Como se pueden calcular hasta n valores y tenemos 5 tipos de monedas:
# T(n) = c₁ + n · 5 · c₂
#
# Complejidad temporal: O(n)
# Esto se debe a que el programa puede calcular diferentes valores desde 0 hasta el monto ingresado y para cada valor revisa las 5 monedas.
#
# Complejidad espacial: O(n)
# Se utiliza memoria para guardar los resultados en memo.
#
# Mejor caso: O(1)
# Si el monto es 0, el programa termina inmediatamente.
#
# Peor caso: O(n)
# Si el monto es grande y todavía no hay resultados guardados, se deben calcular y almacenar muchos valores.

# %% [markdown]
# Grafica:
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 8) Código  funcional **[10 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
monedas = [50, 100, 200, 500, 1000]
memo = {}

def min_monedas(monto):

    if monto == 0:
        return 0

    if monto in memo:
        return memo[monto]

    mejor = monto + 1

    for moneda in monedas:
        if monto >= moneda:
            cantidad = min_monedas(monto - moneda) + 1

            if cantidad < mejor:
                mejor = cantidad

    memo[monto] = mejor
    return mejor


monto = int(input("Ingrese el valor del cambio: "))

while monto < 0 or monto % 50 != 0:
    print("No es posible dar el cambio exacto, ingrese de nuevo")
    monto= int (input())
else:
    resultado = min_monedas(monto)
    print("Cantidad mínima de monedas:", resultado)
# Out:
# Ingrese el valor del cambio: 2000000000050
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_1568/3128667394.py in <cell line: 0>()
#      29     monto= int (input())
#      30 else:
# ---> 31     resultado = min_monedas(monto)
#      32     print("Cantidad mínima de monedas:", resultado)
#
# /tmp/ipykernel_1568/3128667394.py in min_monedas(monto)
#      14     for moneda in monedas:
#      15         if monto >= moneda:
# ---> 16             cantidad = min_monedas(monto - moneda) + 1
#      17
#      18             if cantidad < mejor:
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipykernel_1568/3128667394.py in min_monedas(monto)
#      14     for moneda in monedas:
#      15         if monto >= moneda:
# ---> 16             cantidad = min_monedas(monto - moneda) + 1
#      17
#      18             if cantidad < mejor:
#
# ...

# %% [markdown]
# ## 9) pruebas **[15 pts]**

# %%
def test(input, expected_output):
  # CALCULE LA SOLUCION (asignela a got_output)
  got_output =input
  assert got_output == expected_output, f"se obtuvo {got_output}, pero se esperaba {expected_output}"
  print(f"Paso caso de prueba {input} -> {expected_output}")

# %% [markdown]
# ## Pruebas de enunciado
#
# ¿Qué va aquí?
#
# Casos de prueba proporcionados por el enunciado.
#
# Entrada usada.
#
# Salida esperada.
#
# Salida obtenida.

# %%
input, output = "123", "123"
test(input,output)
# Out:
# Paso caso de prueba 123 -> 123

# %% [markdown]
# ## Pruebas propias
# ¿Qué va aquí?
#
# Casos creados por usted.
#
# Casos tomados de [UDebug](https://www.udebug.com/) (si aplica).

# %%
input, output = "123", "123"
test(input,output)
# Out:
# Paso caso de prueba 123 -> 123

# %% [markdown]
# ## Pruebas de Desempeño
# Qué va aquí?
#
# Medición empírica del tiempo de ejecución.
#
# Gráfica de comportamiento.
#
# Relación entre la gráfica obtenida y el análisis de complejidad teórico.
#
# #### Código base para benchmarking

# %%
# Calcula el tiempo de ejecucion con base a diferentes tamaños de la entrada
# y nos da una lista de resultados, cada resultado contiene el tamaño de la entrada
# y el tiempo de ejecucion
# TENER EN CUENTA ESTAS ENTRADAS PUEDEN VARIAR SEGÚN EL PROBLEMA


def bench(n: int, step: int = 1) -> list[tuple[int, float]]:
    print("Generando datos ...", end='')
    from random import randint
    import time
    results: list[tuple[int, float]] = []


    # AJUSTAR LAS ENTRADAS SEGÚN EL PROBLEMA
    for size in range(1, n, step):
        input = size

        ti = time.perf_counter()
        output = input # Ajustar a su función
        tf = time.perf_counter()


        delta = (tf - ti) * 1000
        print(".", end="")
        results.append((size, delta))
    return results


# === CODIGO PARA DIBUJAR ===


def dibujar(x, y, dimensiones=(7, 5)):
    assert len(x) == len(y)
    import matplotlib.pyplot as plt
    plt.figure(figsize=dimensiones)
    plt.plot(x, y)
    plt.show()


# === LLAMADO ===
tiempos = bench(10, step=1)


x = [size for size, timing in tiempos]
y = [timing for size, timing in tiempos]


dibujar(x, y)
# Out:
# Generando datos ............
